# %% [markdown]
# <a href="https://colab.research.google.com/github/MussaddikKhan/Machine_Learning_Workshop/blob/master/Day_03/DescionTreeUsingSklearnTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data =  {
        "Weather" : ['Sunnn', 'Sunny', 'Windy', 'Rainy', 'Rainy', 'Rainy', 'Windy', 'Windy', 'Windy', 'Sunny'],
        "Parents" : ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No','No', 'Yes', 'No'],
        "Money" : ['Rich', 'Rich', 'Rich', 'Poor', 'Rich', 'Poor', 'Poor', 'Rich', 'Rich', 'Rich'],
        "Descion" : ['Cinema', 'Tennis','Cinema', 'Cinema', 'Stay in', 'Cinema', 'Cinema', 'Stay in', 'Cinema','Tennis']
        }
dataFrame = pd.DataFrame(data)
print(dataFrame)
# Out:
#   Weather Parents Money  Descion
# 0   Sunnn     Yes  Rich   Cinema
# 1   Sunny      No  Rich   Tennis
# 2   Windy     Yes  Rich   Cinema
# 3   Rainy     Yes  Poor   Cinema
# 4   Rainy      No  Rich  Stay in
# 5   Rainy     Yes  Poor   Cinema
# 6   Windy      No  Poor   Cinema
# 7   Windy      No  Rich  Stay in
# 8   Windy     Yes  Rich   Cinema
# 9   Sunny      No  Rich   Tennis

# %%
col = ['Weather', 'Parents', 'Money']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in col:
    dataFrame[i] = le.fit_transform(dataFrame[i])

# %%
from sklearn.model_selection import train_test_split
x = dataFrame[['Weather', 'Parents', 'Money']]
y = dataFrame['Descion']

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state= 10)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion="entropy")
# model = DecisionTreeClassifier
model.fit(x, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9, 'x[1] <= 0.5\nentropy = 1.371\nsamples = 10\nvalue = [6, 2, 2]'),
#  Text(0.3333333333333333, 0.7, 'x[2] <= 0.5\nentropy = 1.522\nsamples = 5\nvalue = [1, 2, 2]'),
#  Text(0.41666666666666663, 0.8, 'True  '),
#  Text(0.16666666666666666, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5, 0.5, 'x[0] <= 1.0\nentropy = 1.0\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.3333333333333333, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6666666666666666, 0.3, 'x[0] <= 2.5\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8333333333333334, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6666666666666666, 0.7, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.5833333333333333, 0.8, '  False')]

# %%
pd.DataFrame({'Variables': x.columns, 'Importance':model.feature_importances_ * 100})
# Out:
#   Variables  Importance
# 0   Weather   29.176836
# 1   Parents   44.493693
# 2     Money   26.329472

# %%
import seaborn as sb
d = sb.load_dataset('iris')
d.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = d[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = d['species']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state= 10)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

model = DecisionTreeClassifier(criterion="entropy")
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
# tree.plot_tree(model)
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plot_tree(model, filled=True)
plt.show()

# %%
pd.DataFrame({'Variables': x.columns, 'Importance':model.feature_importances_ * 100})
# Out:
#       Variables  Importance
# 0  sepal_length    1.695513
# 1   sepal_width    2.687832
# 2  petal_length   90.254910
# 3   petal_width    5.361745
